# %%
PATH = 'VRDL/VRDL_HW1_310554010'
from google.colab import drive
drive.mount('/content/gdrive/')

# !ls gdrive/MyDrive/
# !nvidia-smi

import os
os.chdir('./gdrive/MyDrive/')

os.chdir(f'./{PATH}')
# Out:
# Mounted at /content/gdrive/
#  data	        DLP_final  'Meet Recordings'   tutorial.ipynb   workshop.pdf
# 'data mining'   hw3.ipynb   review_paper       VRDL
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
import torch.utils.data as data
import random as rd
import os
import numpy as np

# %%
rd.seed(0)
flag = list(range(0, 3000))
rd.shuffle(flag)
with open('./dataset/training_labels.txt', 'r') as fp:
    data_list = fp.read().split('\n')

np.savetxt('./dataset/dev_new.txt', [data_list[item] for item in flag[0:300]], fmt='%s') 
np.savetxt('./dataset/train_new.txt', [data_list[item] for item in flag[300:3000]], fmt='%s')
